# %%
import torch
import main
data = torch.load('data/run152752.pt')

# %%
data[0].label
# Out:
# tensor(7.)

# %%
data[0].img_all_classes
# Out:
# tensor([[[[-0.4737, -0.4422, -0.4177,  ..., -0.4286, -0.3939, -0.4035],
#           [-0.4229, -0.3976, -0.4109,  ..., -0.3723, -0.3695, -0.4271],
#           [-0.4029, -0.4042, -0.4205,  ..., -0.4067, -0.3801, -0.3788],
#           ...,
#           [-0.3730, -0.3654, -0.3856,  ..., -0.3918, -0.4189, -0.4000],
#           [-0.3792, -0.4102, -0.4218,  ..., -0.3728, -0.4082, -0.4190],
#           [-0.3671, -0.4179, -0.3998,  ..., -0.3785, -0.4160, -0.3996]],
#
#          [[-0.4869, -0.4367, -0.4138,  ..., -0.2926, -0.2819, -0.4586],
#           [-0.4238, -0.4135, -0.5132,  ..., -0.4154, -0.3478, -0.3775],
#           [-0.4029, -0.5198, -0.5134,  ..., -0.3652, -0.3485, -0.3786],
#           ...,
#           [-0.3270, -0.3788, -0.4413,  ..., -0.4315, -0.3566, -0.3689],
#           [-0.4553, -0.4844, -0.3737,  ..., -0.3882, -0.3494, -0.3505],
#           [-0.3544, -0.4129, -0.4317,  ..., -0.3353, -0.3626, -0.3325]],
#
# ...
